# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import re
import pandas as pd

# %%
def extract_books_from_result(soup):
    returner = {'books': [], 'authors': []}
    for book in soup.find_all('div', attrs={'class':'cmp-text text'}):
        try:
            text = book.text
            pattern = re.compile(r'(?<=. ).+(?=\n)')
            appender = re.findall(pattern,text)[0].split(' by')
            
            if len(appender) > 1:
                returner['books'].append(appender[0])
                returner['authors'].append(appender[1])
                
        except:
            None
            
    returner_df = pd.DataFrame(returner, columns=['books','authors']) 
    
    return returner_df

# %%
url = 'https://www.penguin.co.uk/articles/2018/100-must-read-classic-books/'
r = requests.get(url)
soup = BeautifulSoup(r.text,'html.parser')
results = extract_books_from_result(soup)

# %%
results
# Out:
#                                         books                   authors
# 0                            The Great Gatsby       F. Scott Fitzgerald
# 1               One Hundred Years of Solitude   Gabriel García Márquez
# 2                       To Kill a Mockingbird               Harper Lee
# 3                         Pride and Prejudice               Jane Austen
# 4                               In Cold Blood             Truman Capote
# 5                           Wide Sargasso Sea                 Jean Rhys
# 6                             Brave New World             Aldous Huxley
# 7                        I Capture The Castle               Dodie Smith
# 8                                   Jane Eyre          Charlotte Bronte
# 9                        Crime and Punishment         Fyodor Dostoevsky
# 10                         The Secret History               Donna Tartt
# 11                       The Call of the Wild               Jack London
# 12                             The Chrysalids             John Wyndham
# 13                                 Persuasion               Jane Austen
# 14                                  Moby Dick           Herman Melville
# 15       The Lion, the Witch and the Wardrobe                C.S.Lewis
# 16                          To the Lighthouse            Virginia Woolf
# 17                         Death of the Heart           Elizabeth Bowen
# 18                  Tess of the d'Urbervilles              Thomas Hardy
# 19                               Frankenstein              Mary Shelley
# 20                   The Master and Margarita          Mikhail Bulgakov
# 21                             The Go-Between             L. P. Hartley
# 22            One Flew Over the Cuckoo's Nest                 Ken Kesey
# 23                       Nineteen Eighty-Four             George Orwell
# 24                               Buddenbrooks               Thomas Mann
# 25                        The Grapes of Wrath           John Steinbeck
# 26                                    Beloved             Toni Morrison
# 27                   The Code of the Woosters            P.G. Wodehouse
# 28                                    Dracula               Bram Stoker
# 29                      The Lord of the Rings          J. R. R. Tolkien
# ..                                        ...                       ...
# 70                          Wuthering Heights              Emily Brontë
# 71                                    Perfume           Patrick Süskind
# 72                              War and Peace              Leo Tolstoy
# 73                           Of Human Bondage          Somerset Maugham
# 74                                Bleak House           Charles Dickens
# 75                             Lost Illusions          Honoré de Balzac
# 76                     Breakfast of Champions             Kurt Vonnegut
# 77                          A Christmas Carol          Charles Dickens
# 78                               Silas Marner             George Eliot
# 79                               Mrs Dalloway            Virginia Woolf
# 80                               Little Women         Louisa May Alcott
# 81                           The Sea, The Sea              Iris Murdoch
# 82                              The Godfather                Mario Puzo
# 83                                 The Castle               Franz Kafka
# 84                                I, Claudius             Robert Graves
# 85                                  Peter Pan               J.M. Barrie
# 86                    A Confederacy of Dunces         John Kennedy Tool
# 87                            The Razors Edge          Somerset Maugham
# 88                    Lark Rise to Candleford            Flora Thompson
# 89                       Return of the Native              Thomas Hardy
# 90    A Portrait of the Artist as a Young Man               James Joyce
# 91                          Heart of Darkness             Joseph Conrad
# 92                            North and South         Elizabeth Gaskell
# 93                        The Handmaid's Tale           Margaret Atwood
# 94                            Suite Francaise          Irene Nemorovsky
# 95     One Day in the Life of Ivan Denisovich    Alexander Solzhenitsyn
# 96                           What A Carve Up!              Jonathan Coe
# 97  Zen and the Art of Motorcycle Maintenance             Robert Pirsig
# 98                               White Nights        Fyodor Doestoyesky
# 99                                 Hard Times           Charles Dickens
#
# [100 rows x 2 columns]

# %%
results.to_csv('/Users/gonzaloferreiro/Documents/GitHub/Simple_web_scraper/books_and_authors')
